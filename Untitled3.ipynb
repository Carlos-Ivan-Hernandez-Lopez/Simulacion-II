# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlos-Ivan-Hernandez-Lopez/Simulacion-II/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as rd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def raices():
  u=0
  p=rd.uniform(0,2)
  q=rd.uniform(0,2)
  r=(p**2)-(4*q)
  if r>=0:
    u+=1
  return u

# %%
def experimento(n):
  prom=0
  prob=[]
  for i in range (n):
    prom+=raices()
    prob.append(prom/(i+1))
  return prob

# %%
x=experimento(1000)
plt.plot(x)
Media=np.mean(x)
DesEst=np.std(x)
print(Media,DesEst)
# Out:
# 0.15109574636323833 0.03136391273440381

# %%
N=math.ceil((2*DesEst*1.96/0.01)**2) #El teorema central del limite nos dara una aproximacion a la cantidad de reprticiones que se requieren para que el experimento
print(N)                  #regrese resultados confiables.
# Out:
# 152

# %%
def rep(j):
  lista=[]
  for i in range(j):
    r=experimento(1000)
    lista.append(np.mean(r))
  return lista

# %%
Y=rep(N)
plt.hist(Y)
plt.show()

# %%
X=np.mean(Y)
s=np.std(Y)
print(X,s)
# Out:
# 0.16709321681839515 0.016327424124605996
